# %% [markdown]
# # Generation of trades and returns from a hypothetical strategy

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)

import warnings
warnings.filterwarnings('ignore')

# %%
dates = pd.date_range('1992-01-01', '2012-10-22')
np.random.seed(1)
pnls = np.random.randint(-990, 1000, size=len(dates))
pnls = pnls.cumsum()
positions = np.random.randint(-1, 2, size=len(dates))
positions = positions.cumsum()
strategy_performance = pd.DataFrame(index=dates, data={'PnL': pnls, 'Position': positions})
strategy_performance
# Out:
#               PnL  Position
# 1992-01-01     71         0
# 1992-01-02   -684         0
# 1992-01-03    258         1
# 1992-01-04    364         1
# 1992-01-05   1165         0
# ...           ...       ...
# 2012-10-18  32663       -27
# 2012-10-19  31822       -27
# 2012-10-20  32102       -26
# 2012-10-21  32100       -27
# 2012-10-22  32388       -26
#
# [7601 rows x 2 columns]

# %%
strategy_performance['PnL'].plot(figsize=(12,6), color='black', legend='PnL')
# Out:
# <Axes: >

# %% [markdown]
# # Key Measures of Market Risk

# %% [markdown]
# ## Market Volatility, PnL Variance, PnL Standard Deviation

# %%
strategy_performance['PnLStdev'] = strategy_performance['PnL'].rolling(20).std().fillna(method='backfill')
strategy_performance['PnLStdev'].plot(figsize=(12,6), color='black', legend='PnLStdev')
# Out:
# <Axes: >

# %% [markdown]
# ## Trade Level Sharpe Ratio

# %%
daily_pnl_series = strategy_performance['PnL'].shift(-1) - strategy_performance['PnL']
daily_pnl_series.fillna(0, inplace=True)
avg_daily_pnl = daily_pnl_series.mean()
std_daily_pnl = daily_pnl_series.std()
sharpe_ratio = avg_daily_pnl/std_daily_pnl
sharpe_ratio
# Out:
# 0.007417596376703085

# %%
#check this
annualized_sharpe_ratio = sharpe_ratio * np.sqrt(252)
annualized_sharpe_ratio
# Out:
# 0.11775069203166087

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Maximum Drawdown

# %%
strategy_performance['PnL'].plot(figsize=(12,6), color='black', legend='PnL')
plt.axhline(y=28000, color='darkgrey', linestyle='--', label='PeakPnLBeforeDrawdown')
plt.axhline(y=-15000, color='darkgrey', linestyle=':', label='TroughPnLAfterDrawdown')
plt.vlines(x='2000', ymin=-15000, ymax=28000, label='MaxDrawdown', color='black', linestyle='-.')
plt.legend()

# %%
import zipline.data.bundles as bdl
bdl.__path__
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import zipline.data.bundles as bdl
#       2 bdl.__path__
#
# File ~\anaconda3\envs\algo_env1\lib\site-packages\zipline\__init__.py:29
#      27 from .utils.numpy_utils import numpy_version
#      28 from .utils.pandas_utils import new_pandas
# ---> 29 from .utils.run_algo import run_algorithm
#      31 # These need to happen after the other imports.
#      32 from .algorithm import TradingAlgorithm
#
# File ~\anaconda3\envs\algo_env1\lib\site-packages\zipline\utils\run_algo.py:19
#      16 from toolz import concatv
#      17 from zipline.utils.calendar_utils import get_calendar
# ---> 19 from zipline.data import bundles
#      20 from zipline.data.benchmarks import get_benchmark_returns_from_file
#      21 from zipline.data.data_portal import DataPortal
#
# File ~\anaconda3\envs\algo_env1\lib\site-packages\zipline\data\bundles\__init__.py:4
#       2 from . import quandl  # noqa
#       3 from . import csvdir  # noqa
# ----> 4 from . import quandl_eod # noqa
#       6 from .core import (
#       7     UnknownBundle,
#       8     bundles,
#    (...)
#      16     unregister,
#      17 )
#      20 __all__ = [
#      21     "UnknownBundle",
#      22     "bundles",
#    (...)
#      30     "unregister",
#      31 ]
#
# File ~\anaconda3\envs\algo_env1\lib\site-packages\zipline\data\bundles\quandl_eod.py:15
#      13 from six.moves.urllib.parse import urlencode
#      14 from six import iteritems
# ---> 15 from trading_calendars import register_calendar_alias
#      17 from . import core as bundles
#      18 import numpy as np
#
# ModuleNotFoundError: No module named 'trading_calendars'
